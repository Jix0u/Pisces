# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam

from typing import Dict, List, Optional, Sequence, Tuple
import collections
import datetime
import glob
import numpy as np
import pathlib
import pandas as pd
import pretty_midi

from IPython import display
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Creating the required variables

seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# Sampling rate for audio playback
_SAMPLING_RATE = 16000

# %%
# Setting the path and loading the data

data_dir = pathlib.Path('maestro-v2.0.0')

filenames = glob.glob(str(data_dir/'**/*.mid*'))
print('Number of files:', len(filenames))
# Out:
# Number of files: 1282

# %%
# analyzing and working with a sample file

sample_file = filenames[20]
print(sample_file)

pm = pretty_midi.PrettyMIDI(sample_file)

print('Number of instruments:', len(pm.instruments))
instrument = pm.instruments[0]
instrument_name = pretty_midi.program_to_instrument_name(instrument.program)
print('Instrument name:', instrument_name)

# Extracting the notes
for i, note in enumerate(instrument.notes[:10]):
    note_name = pretty_midi.note_number_to_name(note.pitch)
    duration = note.end - note.start
    print(f'{i}: pitch={note.pitch}, note_name={note_name}, duration={duration:.4f}')
# Out:
# maestro-v2.0.0/2013/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--2.midi
# Number of instruments: 1
# Instrument name: Acoustic Grand Piano
# 0: pitch=52, note_name=E3, duration=1.8333
# 1: pitch=49, note_name=C#3, duration=2.0078
# 2: pitch=57, note_name=A3, duration=1.4987
# 3: pitch=61, note_name=C#4, duration=0.6198
# 4: pitch=64, note_name=E4, duration=0.5182
# 5: pitch=69, note_name=A4, duration=4.2708
# 6: pitch=37, note_name=C#2, duration=12.2279
# 7: pitch=40, note_name=E2, duration=12.0286
# 8: pitch=45, note_name=A2, duration=11.8516
# 9: pitch=57, note_name=A3, duration=0.0443

# %%
# Extracting the notes from the sample MIDI file

def midi_to_notes(midi_file: str) -> pd.DataFrame:
    pm = pretty_midi.PrettyMIDI(midi_file)
    instrument = pm.instruments[0]
    notes = collections.defaultdict(list)

    # Sort the notes by start time
    sorted_notes = sorted(instrument.notes, key=lambda note: note.start)
    prev_start = sorted_notes[0].start

    for note in sorted_notes:
        start = note.start
        end = note.end
        notes['pitch'].append(note.pitch)
        notes['start'].append(start)
        notes['end'].append(end)
        notes['step'].append(start - prev_start)
        notes['duration'].append(end - start)
        prev_start = start

    return pd.DataFrame({name: np.array(value) for name, value in notes.items()})

raw_notes = midi_to_notes(sample_file)
raw_notes.head()
# Out:
#    pitch     start        end      step   duration
# 0     37  1.000000  13.227865  0.000000  12.227865
# 1     40  1.205729  13.234375  0.205729  12.028646
# 2     45  1.398438  13.250000  0.192708  11.851562
# 3     49  1.561198   3.569010  0.162760   2.007812
# 4     52  1.734375   3.567708  0.173177   1.833333

# %%
# Converting to note names by considering the respective pitch values

get_note_names = np.vectorize(pretty_midi.note_number_to_name)
sample_note_names = get_note_names(raw_notes['pitch'])
print(sample_note_names[:10])

# Visualizing the paramaters of the muscial notes of the piano

def plot_piano_roll(notes: pd.DataFrame, count: Optional[int] = None):
    if count:
        title = f'First {count} notes'
    else:
        title = f'Whole track'
        count = len(notes['pitch'])
        
        plt.figure(figsize=(20, 4))
        plot_pitch = np.stack([notes['pitch'], notes['pitch']], axis=0)
        plot_start_stop = np.stack([notes['start'], notes['end']], axis=0)
        
        plt.plot(plot_start_stop[:, :count], plot_pitch[:, :count], color="b", marker=".")
        plt.xlabel('Time [s]')
        plt.ylabel('Pitch')
        _ = plt.title(title)
# Out:
# ['C#2' 'E2' 'A2' 'C#3' 'E3' 'A3' 'C#4' 'E4' 'A4' 'C#3']

# %%
def notes_to_midi(notes: pd.DataFrame, out_file: str, instrument_name: str,
                  velocity: int = 100) -> pretty_midi.PrettyMIDI:

    pm = pretty_midi.PrettyMIDI()
    instrument = pretty_midi.Instrument(
      program=pretty_midi.instrument_name_to_program(
          instrument_name))

    prev_start = 0
    for i, note in notes.iterrows():
        start = float(prev_start + note['step'])
        end = float(start + note['duration'])
        
        note = pretty_midi.Note(velocity=velocity, pitch=int(note['pitch']),
                                start=start, end=end)
        instrument.notes.append(note)
        prev_start = start

    pm.instruments.append(instrument)
    pm.write(out_file)
    return pm

example_file = 'example.midi'
example_pm = notes_to_midi(
    raw_notes, out_file=example_file, instrument_name=instrument_name)

# %%
num_files = 5
all_notes = []
for f in filenames[:num_files]:
    notes = midi_to_notes(f)
    all_notes.append(notes)

all_notes = pd.concat(all_notes)

n_notes = len(all_notes)
print('Number of notes parsed:', n_notes)

key_order = ['pitch', 'step', 'duration']
train_notes = np.stack([all_notes[key] for key in key_order], axis=1)

notes_ds = tf.data.Dataset.from_tensor_slices(train_notes)
notes_ds.element_spec
# Out:
# Number of notes parsed: 15435
# TensorSpec(shape=(3,), dtype=tf.float64, name=None)

# %%
def create_sequences(dataset: tf.data.Dataset, seq_length: int,
                     vocab_size = 128) -> tf.data.Dataset:
    """Returns TF Dataset of sequence and label examples."""
    seq_length = seq_length+1

    # Take 1 extra for the labels
    windows = dataset.window(seq_length, shift=1, stride=1,
                              drop_remainder=True)

    # `flat_map` flattens the" dataset of datasets" into a dataset of tensors
    flatten = lambda x: x.batch(seq_length, drop_remainder=True)
    sequences = windows.flat_map(flatten)

    # Normalize note pitch
    def scale_pitch(x):
        x = x/[vocab_size,1.0,1.0]
        return x

    # Split the labels
    def split_labels(sequences):
        inputs = sequences[:-1]
        labels_dense = sequences[-1]
        labels = {key:labels_dense[i] for i,key in enumerate(key_order)}

        return scale_pitch(inputs), labels

    return sequences.map(split_labels, num_parallel_calls=tf.data.AUTOTUNE)
    
seq_length = 25
vocab_size = 128
seq_ds = create_sequences(notes_ds, seq_length, vocab_size)

# %%
batch_size = 64
buffer_size = n_notes - seq_length  # the number of items in the dataset
train_ds = (seq_ds
            .shuffle(buffer_size)
            .batch(batch_size, drop_remainder=True)
            .cache()
            .prefetch(tf.data.experimental.AUTOTUNE))

# %%
def mse_with_positive_pressure(y_true: tf.Tensor, y_pred: tf.Tensor):
    mse = (y_true - y_pred) ** 2
    positive_pressure = 10 * tf.maximum(-y_pred, 0.0)
    return tf.reduce_mean(mse + positive_pressure)

# %%
input_shape = (seq_length, 3)
learning_rate = 0.005

inputs = Input(input_shape)
x = LSTM(128)(inputs)

outputs = {'pitch': Dense(128, name='pitch')(x),
           'step': Dense(1, name='step')(x),
           'duration': Dense(1, name='duration')(x),
          }

model = Model(inputs, outputs)

loss = {'pitch': SparseCategoricalCrossentropy(from_logits=True),
        'step': mse_with_positive_pressure,
        'duration': mse_with_positive_pressure,
       }

optimizer = Adam(learning_rate=learning_rate)

model.compile(loss=loss, optimizer=optimizer)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 25, 3)]              0         []
#
#  lstm_2 (LSTM)               (None, 128)                  67584     ['input_3[0][0]']
#
#  duration (Dense)            (None, 1)                    129       ['lstm_2[0][0]']
#
#  pitch (Dense)               (None, 128)                  16512     ['lstm_2[0][0]']
#
#  step (Dense)                (None, 1)                    129       ['lstm_2[0][0]']
#
# ==================================================================================================
# Total params: 84354 (329.51 KB)
# Trainable params: 84354 (329.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Creating the necessary callbacks

callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath='./training_checkpoints/ckpt_{epoch}', save_weights_only=True),
             tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5, 
                                              verbose=1, restore_best_weights=True),]

# %%
model.compile(loss = loss, 
              loss_weights = {'pitch': 0.05, 'step': 1.0, 'duration':1.0,},
              optimizer = optimizer)

epochs = 50

history = model.fit(train_ds, 
                    epochs=epochs, 
                    callbacks=callbacks,)
# Out:
# Epoch 1/50
# 240/240 [==============================] - 7s 15ms/step - loss: 0.2714 - duration_loss: 0.0472 - pitch_loss: 4.1037 - step_loss: 0.0191
# Epoch 2/50
# 240/240 [==============================] - 4s 15ms/step - loss: 0.2525 - duration_loss: 0.0429 - pitch_loss: 3.8647 - step_loss: 0.0163
# Epoch 3/50
# 240/240 [==============================] - 4s 16ms/step - loss: 0.2470 - duration_loss: 0.0415 - pitch_loss: 3.7835 - step_loss: 0.0163
# Epoch 4/50
# 240/240 [==============================] - 4s 16ms/step - loss: 0.2428 - duration_loss: 0.0411 - pitch_loss: 3.7040 - step_loss: 0.0165
# Epoch 5/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2393 - duration_loss: 0.0404 - pitch_loss: 3.6540 - step_loss: 0.0162
# Epoch 6/50
# 240/240 [==============================] - 5s 21ms/step - loss: 0.2371 - duration_loss: 0.0398 - pitch_loss: 3.6199 - step_loss: 0.0163
# Epoch 7/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2352 - duration_loss: 0.0394 - pitch_loss: 3.5957 - step_loss: 0.0161
# Epoch 8/50
# 240/240 [==============================] - 5s 21ms/step - loss: 0.2340 - duration_loss: 0.0391 - pitch_loss: 3.5779 - step_loss: 0.0159
# Epoch 9/50
# 240/240 [==============================] - 6s 25ms/step - loss: 0.2333 - duration_loss: 0.0389 - pitch_loss: 3.5708 - step_loss: 0.0159
# Epoch 10/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2324 - duration_loss: 0.0388 - pitch_loss: 3.5569 - step_loss: 0.0157
# Epoch 11/50
# 240/240 [==============================] - 5s 21ms/step - loss: 0.2313 - duration_loss: 0.0384 - pitch_loss: 3.5445 - step_loss: 0.0157
# Epoch 12/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2309 - duration_loss: 0.0381 - pitch_loss: 3.5367 - step_loss: 0.0160
# Epoch 13/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2299 - duration_loss: 0.0380 - pitch_loss: 3.5234 - step_loss: 0.0157
# Epoch 14/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2283 - duration_loss: 0.0373 - pitch_loss: 3.5141 - step_loss: 0.0154
# Epoch 15/50
# 240/240 [==============================] - 5s 21ms/step - loss: 0.2273 - duration_loss: 0.0365 - pitch_loss: 3.5166 - step_loss: 0.0150
# Epoch 16/50
# 240/240 [==============================] - 5s 22ms/step - loss: 0.2279 - duration_loss: 0.0364 - pitch_loss: 3.5234 - step_loss: 0.0154
# Epoch 17/50
# 240/240 [==============================] - 5s 19ms/step - loss: 0.2267 - duration_loss: 0.0363 - pitch_loss: 3.5091 - step_loss: 0.0149
# Epoch 18/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2244 - duration_loss: 0.0350 - pitch_loss: 3.4921 - step_loss: 0.0147
# Epoch 19/50
# 240/240 [==============================] - 4s 16ms/step - loss: 0.2228 - duration_loss: 0.0343 - pitch_loss: 3.4737 - step_loss: 0.0147
# Epoch 20/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2241 - duration_loss: 0.0353 - pitch_loss: 3.4911 - step_loss: 0.0142
# Epoch 21/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2212 - duration_loss: 0.0338 - pitch_loss: 3.4742 - step_loss: 0.0138
# Epoch 22/50
# 240/240 [==============================] - 4s 17ms/step - loss: 0.2212 - duration_loss: 0.0339 - pitch_loss: 3.4625 - step_loss: 0.0142
# Epoch 23/50
# 240/240 [==============================] - 4s 17ms/step - loss: 0.2207 - duration_loss: 0.0337 - pitch_loss: 3.4636 - step_loss: 0.0138
# Epoch 24/50
# 240/240 [==============================] - 5s 19ms/step - loss: 0.2171 - duration_loss: 0.0327 - pitch_loss: 3.4336 - step_loss: 0.0128
# Epoch 25/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2149 - duration_loss: 0.0305 - pitch_loss: 3.4356 - step_loss: 0.0127
# Epoch 26/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2127 - duration_loss: 0.0299 - pitch_loss: 3.4127 - step_loss: 0.0122
# Epoch 27/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2145 - duration_loss: 0.0302 - pitch_loss: 3.4429 - step_loss: 0.0122
# Epoch 28/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2237 - duration_loss: 0.0360 - pitch_loss: 3.5022 - step_loss: 0.0126
# Epoch 29/50
# 240/240 [==============================] - 6s 25ms/step - loss: 0.2131 - duration_loss: 0.0296 - pitch_loss: 3.4264 - step_loss: 0.0121
# Epoch 30/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.2103 - duration_loss: 0.0291 - pitch_loss: 3.3953 - step_loss: 0.0114
# Epoch 31/50
# 240/240 [==============================] - 6s 24ms/step - loss: 0.2076 - duration_loss: 0.0286 - pitch_loss: 3.3720 - step_loss: 0.0104
# Epoch 32/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2074 - duration_loss: 0.0287 - pitch_loss: 3.3696 - step_loss: 0.0102
# Epoch 33/50
# 240/240 [==============================] - 4s 17ms/step - loss: 0.2072 - duration_loss: 0.0285 - pitch_loss: 3.3776 - step_loss: 0.0098
# Epoch 34/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2042 - duration_loss: 0.0276 - pitch_loss: 3.3411 - step_loss: 0.0096
# Epoch 35/50
# 240/240 [==============================] - 7s 29ms/step - loss: 0.2033 - duration_loss: 0.0278 - pitch_loss: 3.3304 - step_loss: 0.0090
# Epoch 36/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2076 - duration_loss: 0.0290 - pitch_loss: 3.3820 - step_loss: 0.0095
# Epoch 37/50
# 240/240 [==============================] - 5s 23ms/step - loss: 0.2045 - duration_loss: 0.0270 - pitch_loss: 3.3540 - step_loss: 0.0098
# Epoch 38/50
# 240/240 [==============================] - 4s 17ms/step - loss: 0.2017 - duration_loss: 0.0261 - pitch_loss: 3.3251 - step_loss: 0.0093
# Epoch 39/50
# 240/240 [==============================] - 4s 17ms/step - loss: 0.2021 - duration_loss: 0.0261 - pitch_loss: 3.3357 - step_loss: 0.0092
# Epoch 40/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.2009 - duration_loss: 0.0262 - pitch_loss: 3.3292 - step_loss: 0.0082
# Epoch 41/50
# 240/240 [==============================] - 5s 19ms/step - loss: 0.2006 - duration_loss: 0.0261 - pitch_loss: 3.3055 - step_loss: 0.0092
# Epoch 42/50
# 240/240 [==============================] - 5s 21ms/step - loss: 0.1965 - duration_loss: 0.0248 - pitch_loss: 3.2652 - step_loss: 0.0084
# Epoch 43/50
# 240/240 [==============================] - 5s 19ms/step - loss: 0.1964 - duration_loss: 0.0244 - pitch_loss: 3.2703 - step_loss: 0.0084
# Epoch 44/50
# 240/240 [==============================] - 5s 20ms/step - loss: 0.1964 - duration_loss: 0.0246 - pitch_loss: 3.2683 - step_loss: 0.0084
# Epoch 45/50
# 240/240 [==============================] - 6s 23ms/step - loss: 0.1979 - duration_loss: 0.0267 - pitch_loss: 3.2547 - step_loss: 0.0085
# Epoch 46/50
# 240/240 [==============================] - 5s 23ms/step - loss: 0.1947 - duration_loss: 0.0249 - pitch_loss: 3.2302 - step_loss: 0.0083
# Epoch 47/50
# 240/240 [==============================] - 5s 22ms/step - loss: 0.1970 - duration_loss: 0.0246 - pitch_loss: 3.2611 - step_loss: 0.0093
# Epoch 48/50
# 240/240 [==============================] - 6s 24ms/step - loss: 0.1998 - duration_loss: 0.0260 - pitch_loss: 3.2772 - step_loss: 0.0099
# Epoch 49/50
# 240/240 [==============================] - 4s 18ms/step - loss: 0.1955 - duration_loss: 0.0253 - pitch_loss: 3.2305 - step_loss: 0.0087
# Epoch 50/50
# 240/240 [==============================] - 4s 17ms/step - loss: 0.1903 - duration_loss: 0.0229 - pitch_loss: 3.1848 - step_loss: 0.0081

# %%
def predict_next_note(notes: np.ndarray, keras_model: tf.keras.Model, 
                      temperature: float = 1.0) -> int:
    """Generates a note IDs using a trained sequence model."""

    assert temperature > 0

    # Add batch dimension
    inputs = tf.expand_dims(notes, 0)

    predictions = model.predict(inputs)
    pitch_logits = predictions['pitch']
    step = predictions['step']
    duration = predictions['duration']

    pitch_logits /= temperature
    pitch = tf.random.categorical(pitch_logits, num_samples=1)
    pitch = tf.squeeze(pitch, axis=-1)
    duration = tf.squeeze(duration, axis=-1)
    step = tf.squeeze(step, axis=-1)

    # `step` and `duration` values should be non-negative
    step = tf.maximum(0, step)
    duration = tf.maximum(0, duration)

    return int(pitch), float(step), float(duration)

# %%
temperature = 2.0
num_predictions = 120

sample_notes = np.stack([raw_notes[key] for key in key_order], axis=1)

# The initial sequence of notes while the pitch is normalized similar to training sequences
input_notes = (
    sample_notes[:seq_length] / np.array([vocab_size, 1, 1]))

generated_notes = []
prev_start = 0

for _ in range(num_predictions):
    pitch, step, duration = predict_next_note(input_notes, model, temperature)
    start = prev_start + step
    end = start + duration
    input_note = (pitch, step, duration)
    generated_notes.append((*input_note, start, end))
    input_notes = np.delete(input_notes, 0, axis=0)
    input_notes = np.append(input_notes, np.expand_dims(input_note, 0), axis=0)
    prev_start = start

generated_notes = pd.DataFrame(
    generated_notes, columns=(*key_order, 'start', 'end'))

generated_notes.head(10)
# Out:
# 1/1 [==============================] - 0s 496ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
#    pitch      step  duration     start       end
# 0     58  0.068264  0.142676  0.068264  0.210940
# 1    100  0.333592  0.000000  0.401856  0.401856
# 2    100  0.295332  0.000000  0.697188  0.697188
# 3     93  0.292157  0.000000  0.989345  0.989345
# 4     98  0.297161  0.000000  1.286506  1.286506
# 5     98  0.296376  0.000000  1.582882  1.582882
# 6     82  0.296912  0.000000  1.879794  1.879794
# 7     98  0.288683  0.000000  2.168477  2.168477
# 8     63  0.284517  0.000000  2.452994  2.452994
# 9     98  0.334557  0.000000  2.787551  2.787551

# %%
out_file = 'output.midi'
out_pm = notes_to_midi(
    generated_notes, out_file=out_file, instrument_name=instrument_name)
